# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait 
from selenium.webdriver import Chrome

# %%
driver = webdriver.Chrome("C:/Users/prasa/Downloads/chromedriver_win32/chromedriver.exe")
# Out:
# C:\Users\prasa\AppData\Local\Temp/ipykernel_2716/806991086.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/Users/prasa/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://www.carwow.co.uk/')

# %%
body_types = driver.find_elements_by_class_name('body-type-list__item')
# Out:
# C:\Users\prasa\AppData\Local\Temp/ipykernel_2716/1792904838.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   body_types = driver.find_elements_by_class_name('body-type-list__item')

# %%
len(body_types)
# Out:
# 8

# %%
for body_type in body_types:
    print(body_type.text)
# Out:
# SUVs
# Hatchbacks
# Saloons
# Coupes
# Estate cars
# People carriers
# Sports cars
# Convertibles

# %%
body_type = body_types[0].text

# %%
body_types[0].click()

# %%
num_cars = driver.find_element_by_class_name('car-chooser__results-count')
# Out:
# C:\Users\prasa\AppData\Local\Temp/ipykernel_2716/2018744891.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   num_cars = driver.find_element_by_class_name('car-chooser__results-count')

# %%
a_string =  num_cars.text
numbers = []
for word in a_string.split():
   if word.isdigit():
      numbers.append(int(word))

# %%
num_cars = numbers[0]

# %%
num_cars
# Out:
# 170

# %%
num_pages = driver.find_elements_by_class_name('pagination__page')
# Out:
# C:\Users\prasa\AppData\Local\Temp/ipykernel_2716/3154419598.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   num_pages = driver.find_elements_by_class_name('pagination__page')

# %%
len(num_pages)
# Out:
# 5

# %%
for num_page in num_pages:
    print(num_page.text)
# Out:
# 1
# 2
# …
# 19

# %%
num_pages = num_pages[len(num_pages)-2].text

# %%
num_pages = int(num_pages)

# %%
num_pages
# Out:
# 19

# %%
buttons = driver.find_elements_by_class_name('btn.btn-action.btn-full-width.btn-short')
# Out:
# C:\Users\prasa\AppData\Local\Temp/ipykernel_2716/720665714.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   buttons = driver.find_elements_by_class_name('btn.btn-action.btn-full-width.btn-short')

# %%
len(buttons)
# Out:
# 9

# %%
car_brands = driver.find_elements_by_class_name('card-generic__sub-title')
# Out:
# C:\Users\prasa\AppData\Local\Temp/ipykernel_2716/3604452563.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   car_brands = driver.find_elements_by_class_name('card-generic__sub-title')

# %%
len(car_brands)
# Out:
# 9

# %%
car_brand = car_brands[0].text

# %%
car_brand
# Out:
# 'Volkswagen'

# %%
car_models = driver.find_elements_by_class_name('card-generic__title')
# Out:
# C:\Users\prasa\AppData\Local\Temp/ipykernel_2716/3212364630.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   car_models = driver.find_elements_by_class_name('card-generic__title')

# %%
len(car_models)
# Out:
# 9

# %%
car_model = car_models[0].text

# %%
car_model
# Out:
# 'T-Cross'

# %%
number_cars = driver.find_element_by_class_name('car-chooser__results-count')
# Out:
# C:\Users\prasa\AppData\Local\Temp/ipykernel_2716/212662880.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   number_cars = driver.find_element_by_class_name('car-chooser__results-count')

# %%
a_string =  number_cars.text
numbers = []
for word in a_string.split():
   if word.isdigit():
      numbers.append(int(word))

# %%
number_cars = numbers[0]

# %%
number_cars
# Out:
# 13

# %%
buttons[0].click()

# %%
show_buttons = driver.find_elements_by_class_name('derivative-details-expander__title')
# Out:
# C:\Users\prasa\AppData\Local\Temp/ipykernel_2716/4165067231.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   show_buttons = driver.find_elements_by_class_name('derivative-details-expander__title')

# %%
len(show_buttons)
# Out:
# 4

# %%
show_buttons[1].click()

# %%
more_buttons = driver.find_elements_by_class_name('derivative-carousel-v2__nav-btn.derivative-carousel-v2__nav-btn--large.derivative-carousel-v2__nav-btn--next')
# Out:
# C:\Users\prasa\AppData\Local\Temp/ipykernel_2716/1231573561.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   more_buttons = driver.find_elements_by_class_name('derivative-carousel-v2__nav-btn.derivative-carousel-v2__nav-btn--large.derivative-carousel-v2__nav-btn--next')

# %%
len(more_buttons)
# Out:
# 2

# %%
more_buttons[1].click()
