# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'

# %%
craiglist = pd.read_excel("craiglist.xlsx")

# %% [markdown]
# Introduction:
#
# We have scraped used car listings from Craiglists using python and we will be:
#
# 1. Data Cleaning
# 2. Data Transformation
# 3. EDA

# %%
craiglist.head()
# Out:
#    Column1  VIN    city  condition    cylinders         date time drive fuel  \
# 0        0  NaN  dallas        NaN          NaN  2022-05-12 06;11   NaN  gas
# 1        1  NaN  dallas  excellent  8 cylinders  2022-05-12 04;52   rwd  gas
# 2        2  NaN  dallas       good  4 cylinders  2022-05-12 04;47   fwd  gas
# 3        3  NaN  dallas       fair          NaN  2022-05-12 04;25   NaN  gas
# 4        4  NaN  dallas       good  4 cylinders  2022-05-12 03;42   fwd  gas
#
#          lat       long  ...           pID  paint color  \
# 0  32.960000 -96.838500  ...  7.482630e+09          NaN
# 1  36.357700 -94.222400  ...  7.482622e+09        white
# 2  33.025200 -96.195645  ...  7.482621e+09         grey
# 3  33.427426 -94.150944  ...  7.482620e+09        white
# 4  33.215654 -96.749039  ...  7.482618e+09       silver
#
#                                            post_body   price      size  \
# 0                            MOTOR V8 6 1 HEMI 432hp  200000       NaN
# 1  Perfect pearl 2002 SC hardtop convertible With...   20000  mid-size
# 2                             2013 Honda Civic Sedan   11500       NaN
# 3                                          199K call    3300       NaN
# 4                           107292 miles Clean Title    7000  mid-size
#
#   title status transmission         type              year make model  \
# 0        clean       manual          NaN    1970 plymouth road runner
# 1        clean    automatic  convertible             2002 Lexus SC430
# 2        clean    automatic        sedan  2013 2013 Honda Civic sedan
# 3        clean    automatic          van                1995 ford van
# 4        clean    automatic        sedan                2012 VW Jetta
#
#            year_c make model
# 0  1970 plymouth road runner
# 1           2002 Lexus SC430
# 2     2013 Honda Civic sedan
# 3              1995 ford van
# 4              2012 VW Jetta
#
# [5 rows x 21 columns]

# %%
craiglist.tail()
# Out:
#        Column1  VIN     city condition    cylinders         date time drive  \
# 21450    21450  NaN  seattle      good  8 cylinders  2022-05-03 17;50   4wd
# 21451    21451  NaN  seattle      good          NaN  2022-05-03 17;46   NaN
# 21452    21452  NaN  seattle       NaN          NaN  2022-05-03 17;41   NaN
# 21453    21453  NaN  seattle       NaN          NaN  2022-05-03 17;37   NaN
# 21454    21454  NaN  seattle       NaN          NaN  2022-05-03 17;30   NaN
#
#          fuel        lat        long  ...           pID  paint color  \
# 21450  diesel  47.490041 -122.131319  ...  7.479230e+09         grey
# 21451  diesel  47.146400 -122.457200  ...  7.479229e+09        white
# 21452     gas  47.305000 -122.206700  ...  7.479227e+09          NaN
# 21453     gas  47.988400 -122.200600  ...  7.479226e+09          NaN
# 21454     gas  47.611400 -122.330500  ...  7.479224e+09          NaN
#
#                                                post_body  price       size  \
# 21450           2003 Ford F 350 Diesel Lariat 4 x 4 6 0L  27500  full-size
# 21451  I am selling my Chrysler 300 for 1600 and I am...   1650        NaN
# 21452  I have for sale a 2012 tl all wheel drive v6 3...  15000        NaN
# 21453               1993 GMC Sierra Single CAB Short Bed  13999        NaN
# 21454  Selling out r 1984 Silverado long box classic ...   7500        NaN
#
#       title status transmission    type         year make model  \
# 21450        clean       manual  pickup          2003 Ford F350
# 21451        clean       manual     NaN  2007 2007 chrysler 300
# 21452        clean    automatic     NaN           2012 Acura TL
# 21453        clean    automatic     NaN         1993 GMC Sierra
# 21454        clean    automatic     NaN    1984 chevy silverado
#
#           year_c make model
# 21450        2003 Ford F350
# 21451     2007 chrysler 300
# 21452         2012 Acura TL
# 21453       1993 GMC Sierra
# 21454  1984 chevy silverado
#
# [5 rows x 21 columns]

# %%
craiglist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21455 entries, 0 to 21454
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Column1            21455 non-null  int64
#  1   VIN                3331 non-null   object
#  2   city               21455 non-null  object
#  3   condition          17818 non-null  object
#  4   cylinders          16170 non-null  object
#  5   date time          21455 non-null  object
#  6   drive              14602 non-null  object
#  7   fuel               21455 non-null  object
#  8   lat                21443 non-null  float64
#  9   long               21443 non-null  float64
#  10  odometer           21455 non-null  int64
#  11  pID                21443 non-null  float64
#  12  paint color        15540 non-null  object
#  13  post_body          21237 non-null  object
#  14  price              21455 non-null  int64
#  15  size               10787 non-null  object
#  16  title status       21455 non-null  object
#  17  transmission       21455 non-null  object
#  18  type               14144 non-null  object
#  19  year make model    21455 non-null  object
#  20  year_c make model  21455 non-null  object
# dtypes: float64(3), int64(3), object(15)
# memory usage: 3.4+ MB

# %%
# Summary statistics for any numerical column:
craiglist.describe()
# Out:
#             Column1           lat          long      odometer           pID  \
# count  21455.000000  21443.000000  21443.000000  2.145500e+04  2.144300e+04
# mean   10727.000000     36.343634    -94.196912  1.452386e+05  7.479739e+09
# std     6193.669349      5.853224     17.684743  3.235259e+05  2.647754e+06
# min        0.000000    -83.256660   -124.185121  0.000000e+00  7.470651e+09
# 25%     5363.500000     32.934600   -112.037000  7.400000e+04  7.478395e+09
# 50%    10727.000000     36.003000    -88.192100  1.220000e+05  7.480553e+09
# 75%    16090.500000     40.727700    -77.595561  1.700000e+05  7.481719e+09
# max    21454.000000     48.970800    135.961210  1.000000e+07  7.482635e+09
#
#               price
# count  2.145500e+04
# mean   1.694276e+04
# std    1.112229e+05
# min    0.000000e+00
# 25%    5.000000e+03
# 50%    9.500000e+03
# 75%    1.849300e+04
# max    1.234568e+07

# %% [markdown]
# In total, we have 21455 rows with 20 columns in the dataset. As these columns at this point seems relevant, we will not be dropping any columns yet. The data types seems in the right order as well from a glance, we will double check on the column "date time" if it is in the right datetime format.

# %%
craiglist.loc[:,"date time"]
# Out:
# 0        2022-05-12 06;11
# 1        2022-05-12 04;52
# 2        2022-05-12 04;47
# 3        2022-05-12 04;25
# 4        2022-05-12 03;42
#                ...
# 21450    2022-05-03 17;50
# 21451    2022-05-03 17;46
# 21452    2022-05-03 17;41
# 21453    2022-05-03 17;37
# 21454    2022-05-03 17;30
# Name: date time, Length: 21455, dtype: object

# %% [markdown]
# It seems like the "date time" column is in the right data type as well.

# %%
percent_missing = craiglist.isnull().sum() * 100 / len(craiglist)
missing_value_df = pd.DataFrame({'Missing Values': craiglist.isna().sum(),
                                 'Percentage': round(percent_missing, 2)})
missing_value_df
# Out:
#                    Missing Values  Percentage
# Column1                         0        0.00
# VIN                         18124       84.47
# city                            0        0.00
# condition                    3637       16.95
# cylinders                    5285       24.63
# date time                       0        0.00
# drive                        6853       31.94
# fuel                            0        0.00
# lat                            12        0.06
# long                           12        0.06
# odometer                        0        0.00
# pID                            12        0.06
# paint color                  5915       27.57
# post_body                     218        1.02
# price                           0        0.00
# size                        10668       49.72
# title status                    0        0.00
# transmission                    0        0.00
# type                         7311       34.08
# year make model                 0        0.00
# year_c make model               0        0.00

# %% [markdown]
# We may drop the variable VIN as it is missing more than 80% of the values out of the dataset

# %%
# sum(craiglist.isna().sum())

# %%
# To check the list of cities that we scraped from
pd.unique(craiglist["city"])
# Out:
# array(['dallas', 'chicago', 'newyork', 'sfbay', 'losangeles', 'houston',
#        'phoenix', 'philadelphia', 'sanantonio', 'washingtondc', 'boston',
#        'nashville', 'atlanta', 'miami', 'seattle'], dtype=object)

# %%
# Count how many listing per cities
craiglist[["city","date time"]].groupby(by=["city"]).count().sort_values("date time",ascending=False)
# Out:
#               date time
# city
# newyork            1664
# chicago            1660
# houston            1643
# atlanta            1607
# dallas             1601
# miami              1595
# seattle            1577
# losangeles         1556
# washingtondc       1541
# phoenix            1534
# sfbay              1511
# boston             1374
# sanantonio         1059
# philadelphia        882
# nashville           651

# %%
sns.set(rc = {'figure.figsize':(18,8)})
ax = sns.countplot(x="city", data=craiglist, color='#5975a4')
ax.tick_params(axis='x', rotation=30)
ax.set_xlabel("City");
ax.set_ylabel("Vehicle Counts");
ax.set_title("Used Vehicles Counts by City");

# %% [markdown]
# It seems like majority of the cities have more than 1500 used car listings with the exception of Boston, San Antonio while Philadelphia and Nashville only have lesser than 1,000 postings.

# %%
# Identify the range of data on the carlisting
print(craiglist["date time"].min(),craiglist["date time"].max())
# Out:
# 2022-04-13 05;23 2022-05-12 07;46

# %% [markdown]
# The range of the used car listing is from 13th April 2022 up until 12th May 2022, across the span of a month.

# %%
# Subsetting dataset for EDA
EDA = pd.DataFrame()
EDA["day"] = pd.DatetimeIndex(craiglist["date time"].str[:10]).day

sns.set(rc = {'figure.figsize':(15,8)})

ax = sns.histplot(x="day", data=EDA)

ax.set_title("Used Vehicles Posts Throughout The 30 Days");
ax.set_xlabel("Day");
ax.set_ylabel("Used Car Post Counts");

# %% [markdown]
# We can see here that the number of posts per day peaks on the 9th - 11th day (22 - 24 April 2022) which are Friday - Sunday. However, the number of posts drops dramatically after those dates.

# %%
# Display the average price of used car listing based on cities
craiglist[["city","price"]].groupby(by=["city"]).mean().round(2).sort_values("price",ascending=False)
# Out:
#                  price
# city
# washingtondc  21591.87
# newyork       20816.55
# phoenix       19071.58
# losangeles    18589.29
# dallas        17528.53
# sfbay         16778.99
# miami         16587.26
# chicago       16362.90
# seattle       16125.17
# houston       15529.46
# nashville     15043.09
# boston        14961.49
# sanantonio    14343.42
# philadelphia  13875.75
# atlanta       13476.34

# %%
# Plot another plot for price against car type
fig = plt.subplots(1,1,figsize=(18,5))

ax = sns.barplot(x="price", y="type", data=craiglist)
ax.set_title("Craiglist Used Vehicles by Car Type");
ax.set_xlabel("Car Price");
ax.set_ylabel("Car Type");

# %% [markdown]
# It is observed that "Offroad" type has the highest selling prices followed by "other" and "truck".

# %%
# Plot boxplot for price
plt.subplots(1,1,figsize=(18,7))

ax = sns.boxplot(x="type", y="price", data=craiglist)

ax.set_title("Used Vehicles Posts Throughout The 30 Days");
ax.set_xlabel("Car Type");
ax.set_ylabel("Used Car Price");

# %% [markdown]
# There seem to be an extreme outlier on SUV price which we might need to remove later on in the data cleaning process.

# %%
# Plot boxplot for price without SUV
sns.set(rc = {'figure.figsize':(15,8)})


craiglist_copy = craiglist.copy()
craiglist_copy = craiglist_copy[craiglist_copy.type != "SUV"]

ax = sns.boxplot(x="type", y="price", data=craiglist_copy)

ax.set_title("Used Vehicles Posts Throughout The 30 Days");
ax.set_xlabel("Car Type");
ax.set_ylabel("Used Car Price");

# %%
# craiglist.type.unique()

# %%
craiglist[["price","type"]].groupby("type").max()
# Out:
#                 price
# type
# SUV          12345678
# bus            110000
# convertible    450000
# coupe          550000
# hatchback       84850
# mini-van        78869
# offroad        475000
# other          425000
# pickup         137000
# sedan          179000
# truck          315000
# van            139900
# wagon           70000

# %% [markdown]
# It seems like the one of the value of the SUV listing might be inputted with incorrect data and we will remove that at the data cleaning part

# %%
pd.DataFrame(craiglist["year make model"].astype(str).str[:4].value_counts().sort_values(ascending=False).head())
# Out:
#       year make model
# 2007             1193
# 2008             1193
# 2013             1185
# 2006             1102
# 2012             1076

# %% [markdown]
# It turns out that most of the cars that were made between 2006 and 2013 had the most used car postings in Craiglist. . The mode age of a car on Craigslist is around 12 years old but I wonder which vehicle brands dominate these ads.

# %%
# plot most popular brands
fig, ax = plt.subplots(1,1,figsize=(18,5))
ax = craiglist["year make model"].value_counts(sort = True)[:39]\
               .plot.bar(title='Used Vehicles Counts by Make')

# %%
# Number of job postings for Honda, Ford and Toyota
print(craiglist["year make model"].str.contains("honda|ford|toyota").sum()/len(craiglist))
# Out:
# 0.22069447681193194

# %% [markdown]
# Ford, Nissan and Toyota seems to be the more popular car make/brands which makes up of 22% of the data. There seem to have a good amount of japanese car make in the used car postings.

# %%
# plot most popular colors
fig, ax = plt.subplots(1,1,figsize=(18,5))
fig = craiglist[craiglist["paint color"].notna()]["paint color"]\
       .value_counts(sort = True).plot.bar(title='Used Vehicles Counts by Color')
fig = plt.xticks(rotation=0)

# %%
craiglist["paint color"].value_counts()
# Out:
# white     3733
# black     3084
# silver    1996
# grey      1793
# blue      1636
# red       1479
# green      639
# brown      438
# custom     341
# yellow     222
# orange     128
# purple      51
# Name: paint color, dtype: int64

# %% [markdown]
# The color "white" is the most popular followed by "black" and "silver". The top 3 color has a total 8,813 postings over 15,540 posts which accounts for more than 50% of the postings.

# %%
craiglist.boxplot(column='odometer', return_type='axes');

# %% [markdown]
# The box plot shows the odometer for used cars. It can be seen that most used cars have an odometer reading of less than 300000.

# %%
# Plot transmission
fig, ax = plt.subplots(1,1,figsize=(18,5))

# plot with histogram
fig = ax.hist(craiglist["transmission"])

# set labels and title
fig = ax.set_title("Craiglist Used Vehicles by Transmission Type")
fig = ax.set_xlabel("Transmission")
fig = ax.set_ylabel("Vehicle Counts")

# %%
craiglist["transmission"].value_counts()
# Out:
# automatic    18456
# manual        2775
# other          224
# Name: transmission, dtype: int64

# %% [markdown]
# Most of the used car posting is with Automatic transmission which is more than 86% of the total used car postings in Craiglist

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Dropping Columns

# %%
# Drop VIN column as it has more than 80% missing values
craiglist = craiglist.drop(columns=['VIN'])

# %%
# Drop Column1 and pID as it does not affect the class variable
craiglist = craiglist.drop(columns=['city', 'condition', 'cylinders', 'date time', 'drive', 'lat', 
                                    'long', 'post_body', 'size', 'title status', 'type', 'pID', 'Column1'])

# %%
# Drop 'year make model' as it is a duplicate column
craiglist = craiglist.drop(columns=['year make model'])

# %%
craiglist.head()
# Out:
#   fuel  odometer paint color   price transmission          year_c make model
# 0  gas    111111         NaN  200000       manual  1970 plymouth road runner
# 1  gas     90000       white   20000    automatic           2002 Lexus SC430
# 2  gas    160600        grey   11500    automatic     2013 Honda Civic sedan
# 3  gas    199000       white    3300    automatic              1995 ford van
# 4  gas    107292      silver    7000    automatic              2012 VW Jetta

# %% [markdown]
# ### Splitting 'year_c make model'

# %%
craiglist1 = craiglist['year_c make model'].str.split(' ', n=3, expand=True)

# %%
craiglist = craiglist.join(craiglist1)

# %%
craiglist.head(10)
# Out:
#   fuel  odometer paint color   price transmission  \
# 0  gas    111111         NaN  200000       manual
# 1  gas     90000       white   20000    automatic
# 2  gas    160600        grey   11500    automatic
# 3  gas    199000       white    3300    automatic
# 4  gas    107292      silver    7000    automatic
# 5  gas     80245      silver   11500       manual
# 6  gas     50280       black   31995    automatic
# 7  gas    176000       white    3900    automatic
# 8  gas    165000         NaN    8500    automatic
# 9  gas     55000         NaN   18500    automatic
#
#                       year_c make model     0          1          2  \
# 0             1970 plymouth road runner  1970   plymouth       road
# 1                      2002 Lexus SC430  2002      Lexus      SC430
# 2                2013 Honda Civic sedan  2013      Honda      Civic
# 3                         1995 ford van  1995       ford        van
# 4                         2012 VW Jetta  2012         VW      Jetta
# 5                     2015 chevy camaro  2015      chevy     camaro
# 6  2015 chevrolet silverado 1500 lt 4x4  2015  chevrolet  silverado
# 7                      2000 lexus es300  2000      lexus      es300
# 8            2005 bmw 325ci convertible  2005        bmw      325ci
# 9                      2017 toyota rav4  2017     toyota       rav4
#
#              3
# 0       runner
# 1         None
# 2        sedan
# 3         None
# 4         None
# 5         None
# 6  1500 lt 4x4
# 7         None
# 8  convertible
# 9         None

# %%
craiglist.rename(columns={0: 'year', 1: 'brand', 2: 'model', 3: 'variant'}, inplace=True)

# %%
craiglist.head(10)
# Out:
#   fuel  odometer paint color   price transmission  \
# 0  gas    111111         NaN  200000       manual
# 1  gas     90000       white   20000    automatic
# 2  gas    160600        grey   11500    automatic
# 3  gas    199000       white    3300    automatic
# 4  gas    107292      silver    7000    automatic
# 5  gas     80245      silver   11500       manual
# 6  gas     50280       black   31995    automatic
# 7  gas    176000       white    3900    automatic
# 8  gas    165000         NaN    8500    automatic
# 9  gas     55000         NaN   18500    automatic
#
#                       year_c make model  year      brand      model  \
# 0             1970 plymouth road runner  1970   plymouth       road
# 1                      2002 Lexus SC430  2002      Lexus      SC430
# 2                2013 Honda Civic sedan  2013      Honda      Civic
# 3                         1995 ford van  1995       ford        van
# 4                         2012 VW Jetta  2012         VW      Jetta
# 5                     2015 chevy camaro  2015      chevy     camaro
# 6  2015 chevrolet silverado 1500 lt 4x4  2015  chevrolet  silverado
# 7                      2000 lexus es300  2000      lexus      es300
# 8            2005 bmw 325ci convertible  2005        bmw      325ci
# 9                      2017 toyota rav4  2017     toyota       rav4
#
#        variant
# 0       runner
# 1         None
# 2        sedan
# 3         None
# 4         None
# 5         None
# 6  1500 lt 4x4
# 7         None
# 8  convertible
# 9         None

# %%
# Drop 'year_c make model' after splitting
craiglist = craiglist.drop(columns=['year_c make model'])

# %%
craiglist.head(10)
# Out:
#   fuel  odometer paint color   price transmission  year      brand      model  \
# 0  gas    111111         NaN  200000       manual  1970   plymouth       road
# 1  gas     90000       white   20000    automatic  2002      Lexus      SC430
# 2  gas    160600        grey   11500    automatic  2013      Honda      Civic
# 3  gas    199000       white    3300    automatic  1995       ford        van
# 4  gas    107292      silver    7000    automatic  2012         VW      Jetta
# 5  gas     80245      silver   11500       manual  2015      chevy     camaro
# 6  gas     50280       black   31995    automatic  2015  chevrolet  silverado
# 7  gas    176000       white    3900    automatic  2000      lexus      es300
# 8  gas    165000         NaN    8500    automatic  2005        bmw      325ci
# 9  gas     55000         NaN   18500    automatic  2017     toyota       rav4
#
#        variant
# 0       runner
# 1         None
# 2        sedan
# 3         None
# 4         None
# 5         None
# 6  1500 lt 4x4
# 7         None
# 8  convertible
# 9         None

# %% [markdown]
# ### Drop SUV Outlier

# %%
suv_outlier = craiglist.index.get_loc(craiglist.query('price > 12000000').index[0])
suv_outlier
# Out:
# 13800

# %%
#print(np.where(craiglist['price']>12000000))

# %%
#Viewing outlier row
#craiglist.iloc[[13800]]
craiglist.iloc[[suv_outlier]]
# Out:
#       fuel  odometer paint color     price transmission  year     brand model  \
# 13800  gas     67000       green  12345678    automatic  1967  Suburban  None
#
#       variant
# 13800    None

# %%
# Drop outlier
#craiglist = craiglist.drop([13800])
craiglist = craiglist.drop([suv_outlier])

# %%
print(np.where(craiglist['price']>12000000))
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# ### Drop rows with more than 2 missing values

# %%
craiglist.shape
# Out:
# (21454, 9)

# %%
# Drop rows that contain less than 7 non-missing values
craiglist = craiglist.dropna(thresh=7)

# %%
# Shape after dropping rows with more than 2 missing values
craiglist.shape
# Out:
# (21063, 9)

# %% [markdown]
# ### Imputing missing values with 'unknown'

# %%
percent_missing = craiglist.isnull().sum() * 100 / len(craiglist)
missing_value_df = pd.DataFrame({'Missing Values': craiglist.isna().sum(),
                                 'Percentage': round(percent_missing, 2)})
missing_value_df
# Out:
#               Missing Values  Percentage
# fuel                       0        0.00
# odometer                   0        0.00
# paint color             5546       26.33
# price                      0        0.00
# transmission               0        0.00
# year                       0        0.00
# brand                      0        0.00
# model                    407        1.93
# variant                11384       54.05

# %%
craiglist['paint color'] = craiglist['paint color'].fillna("Unknown")
craiglist['model'] = craiglist['model'].fillna("Unknown")
craiglist['variant'] = craiglist['variant'].fillna("Unknown")

# %%
# Check missing values
percent_missing = craiglist.isnull().sum() * 100 / len(craiglist)
missing_value_df = pd.DataFrame({'Missing Values': craiglist.isna().sum(),
                                 'Percentage': round(percent_missing, 2)})
missing_value_df
# Out:
#               Missing Values  Percentage
# fuel                       0         0.0
# odometer                   0         0.0
# paint color                0         0.0
# price                      0         0.0
# transmission               0         0.0
# year                       0         0.0
# brand                      0         0.0
# model                      0         0.0
# variant                    0         0.0

# %% [markdown]
# The craiglist dataset now has 0 missing values

# %% [markdown]
# ### Checking extreme values

# %% [markdown]
# #### Price

# %%
craiglist[craiglist.price == 0].shape
# Out:
# (1, 9)

# %%
craiglist[craiglist.price < 400].shape
# Out:
# (273, 9)

# %%
craiglist.loc[craiglist['price'] < 400]
# Out:
#          fuel  odometer paint color  price transmission  year    brand  \
# 131    diesel    120000         red      1    automatic  1998      HME
# 228       gas     58000       black     12    automatic  1985  Spartan
# 626       gas     53000       black      1       manual  1986  pontiac
# 650       gas     44400     Unknown     21       manual  1966     ford
# 934       gas    154000      silver      1    automatic  2011     FORD
# ...       ...       ...         ...    ...          ...   ...      ...
# 20803  diesel     83000         red      1    automatic  2005     Ford
# 20884     gas    134000     Unknown      1    automatic  2004    dodge
# 21142  diesel    190000       white      1    automatic  2005     Ford
# 21241     gas    112000     Unknown      1    automatic  2006    Volvo
# 21435     gas    100000         red     14    automatic  1961    chevy
#
#          model      variant
# 131    Ferrara  Aerial 1871
# 228    Unknown      Unknown
# 626      fiero           gt
# 650       f250      Unknown
# 934       FLEX      Unknown
# ...        ...          ...
# 20803     F550      Unknown
# 20884      ram         1500
# 21142    F-550      Unknown
# 21241      v50      Unknown
# 21435   impala      Unknown
#
# [273 rows x 9 columns]

# %% [markdown]
# Cars priced less than a 400 only represents a small number of buyers and contains a lot of noise.These rows will be dropped

# %%
craiglist[craiglist.price > 1000000].shape
# Out:
# (3, 9)

# %%
craiglist.loc[craiglist['price'] > 1000000]
# Out:
#       fuel  odometer paint color     price transmission  year          brand  \
# 3953   gas    197000     Unknown  10000000    automatic  1960         Toyota
# 6697   gas      7652     Unknown   1399999    automatic  2015  mercedes-benz
# 18358  gas      7652     Unknown   1399999    automatic  2015       Mercedez
#
#         model    variant
# 3953    Prius         IV
# 6697        g  63 brabus
# 18358  Brabus        6x6

# %% [markdown]
# Cars priced more than 1000000 looks to be fine, hence, it will be kept.

# %%
craiglist = craiglist[(craiglist.price > 400)]

# %% [markdown]
# Cars priced less than 400 have been removed

# %% [markdown]
# #### Odometer

# %%
craiglist[craiglist.odometer == 0].shape
# Out:
# (25, 9)

# %%
craiglist[craiglist.odometer > 3000000].shape
# Out:
# (26, 9)

# %%
craiglist.loc[craiglist['odometer'] > 3000000]
# Out:
#          fuel  odometer paint color  price transmission  year          brand  \
# 1009      gas   7777777        grey   7900    automatic  1946     Studebaker
# 1185      gas   9999999     Unknown   8995    automatic  1939      chevrolet
# 1398      gas   9999999     Unknown   4500        other  1940           ford
# 1465      gas  10000000         red  11000       manual  1941          chevy
# 3125      gas  10000000      yellow  10800    automatic  1972     Oldsmobile
# 5257      gas   7777777       white   2500    automatic  2004           2005
# 6665      gas   9999999     Unknown   8500    automatic  2018          Honda
# 7265      gas   8888888      silver  38500       manual  1935        packard
# 8887      gas   9999999     Unknown   8995    automatic  1939      chevrolet
# 9356   diesel   9670629       white  55000       manual  2013   freightliner
# 9670      gas   9999999     Unknown   4900       manual  1980           Jeep
# 9700      gas  10000000     Unknown   5500    automatic  1973       plymouth
# 9847      gas   7777777        grey   7900    automatic  1946     Studebaler
# 9906      gas   3333333       black   4000    automatic  1986            gmc
# 9927      gas   3333333       black   4000    automatic  1986            gmc
# 10000   other   6666666     Unknown    600        other  1971             71
# 10422     gas  10000000     Unknown   3450       manual  1973           opel
# 11347     gas   9999999     Unknown   2500       manual  1966  international
# 11649  diesel   3584566     Unknown  49000    automatic  2005           MACK
# 11706  diesel   4444444     Unknown  13500       manual  2003  international
# 13035     gas   9999999        grey   7900    automatic  1946     Studebaker
# 13089     gas  10000000       white  10500    automatic  1979        pontiac
# 15334     gas   3100010     Unknown   1000    automatic  1980         jaguar
# 16723  diesel   6100007     Unknown  49500       manual  2013   freightliner
# 16826     gas   5600088       black  28000    automatic  2015         toyota
# 16897     gas   7827751       green  55000    automatic  1972     oldsmobile
#
#            model        variant
# 1009        Step   Van --M16-28
# 1185      master         deluxe
# 1398       sedan        Unknown
# 1465       truck        Unknown
# 3125     Cutlass        S  Olds
# 5257         kia         sedona
# 6665      Accord        Unknown
# 7265     Unknown        Unknown
# 8887      master         deluxe
# 9356    cascadia        sleeper
# 9670    Wrangler        Unknown
# 9700   satellite        Unknown
# 9847      M16-28       Step Van
# 9906      sierra        Unknown
# 9927      sierra        Unknown
# 10000          f            250
# 10422         gt        Unknown
# 11347      scout        Unknown
# 11649      CV713        Unknown
# 11706       4400        Unknown
# 13035       Step  Van -- M16-28
# 13089      trans             am
# 15334        xj6        Unknown
# 16723   cascadia        Unknown
# 16826    4runner        Unknown
# 16897    cutlass        supreme

# %% [markdown]
# Cars with odometer of 0 will be dropped because it is not considered a used car.
# Cars with odometer of more than 3 million will also be dropped as it contains noise.

# %%
#round((sum(craiglist['odometer'] > 1000000) / len(craiglist.index)) * 100, 2)

# %%
craiglist = craiglist[(craiglist.odometer > 0) & (craiglist.odometer < 3000000)]

# %%
craiglist.shape
# Out:
# (20736, 9)

# %% [markdown]
# #### Year

# %%
print(sorted(pd.unique(craiglist["year"])))
# Out:
# ['1916', '1918', '1921', '1922', '1923', '1924', '1925', '1926', '1927', '1928', '1929', '1930', '1931', '1932', '1933', '1934', '1935', '1936', '1937', '1938', '1939', '1940', '1941', '1942', '1945', '1946', '1947', '1948', '1949', '1950', '1951', '1952', '1953', '1954', '1955', '1956', '1957', '1958', '1959', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2006.', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']

# %% [markdown]
# There seems to be a noise for "2006." as it has a period after the year. The row will be inspected.

# %%
#craiglist['year'].value_counts()
sum(craiglist['year'] == "2006.")
# Out:
# 1

# %%
#year_noise = np.where(craiglist['year'] == "2006.")
#year_noise = craiglist[craiglist['year'] == '2006.'].index[0]

# %%
year_noise = craiglist.index.get_loc(craiglist.query('year == "2006."').index[0])
year_noise
# Out:
# 15450

# %%
craiglist.iloc[[year_noise]]
# Out:
#       fuel  odometer paint color  price transmission   year brand model  \
# 16004  gas    159000     Unknown   4899       manual  2006.  Ford  F150
#
#        variant
# 16004  Unknown

# %% [markdown]
# Since everything looks to be good, we can just remove the period in the year.

# %%
craiglist["year"].replace({"2006.": 2006}, inplace=True)

# %%
#craiglist.iloc[[15713]]
craiglist.iloc[[year_noise]]
# Out:
#       fuel  odometer paint color  price transmission  year brand model  \
# 16004  gas    159000     Unknown   4899       manual  2006  Ford  F150
#
#        variant
# 16004  Unknown

# %% [markdown]
# There also appear to be a year '2023' which have not been released.

# %%
craiglist.loc[craiglist['year'] == "2023"]
# Out:
#          fuel  odometer paint color   price transmission  year          brand  \
# 2667   diesel        10       white  225000    automatic  2023  international
# 3443      gas       101       white   96950    automatic  2023           land
# 4272      gas        29       black  185000    automatic  2023           land
# 12985     gas       504       white   47550    automatic  2023            kia
# 18915  diesel       250       white  135995    automatic  2023   FREIGHTLINER
# 18918  diesel       250       white  149999    automatic  2023   freightliner
# 19024   other      1995     Unknown    1995    automatic  2023           alfa
#
#           model          variant
# 2667    prostar          Unknown
# 3443      rover     defender 110
# 4272      rover  defender 110 v8
# 12985  sportage      ex 2.4l awd
# 18915        M2              112
# 18918        m2          Unknown
# 19024     romeo          Unknown

# %% [markdown]
# The rows with year 2023 will be dropped

# %%
craiglist.drop(craiglist[craiglist['year'] == "2023"].index, inplace = True)

# %%
np.where(craiglist['year'] == "2023")
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# ### Convert Brand, Model and Variant to lowercase

# %% [markdown]
# Certain values in brand, model and variant have the same values but in different cases. For example, in brand, there are some values with 'Toyota' and some with 'toyota'. Since Python is case sensitive it will intepret this as two different brands. Hence it will all be changed to lowercase.

# %%
craiglist['brand'] = craiglist['brand'].str.lower()
craiglist['model'] = craiglist['model'].str.lower()
craiglist['variant'] = craiglist['variant'].str.lower()
craiglist['fuel'] = craiglist['fuel'].str.lower()
craiglist['paint color'] = craiglist['paint color'].str.lower()

# %%
craiglist.head(50)
# Out:
#         fuel  odometer paint color   price transmission  year          brand  \
# 0        gas    111111     unknown  200000       manual  1970       plymouth
# 1        gas     90000       white   20000    automatic  2002          lexus
# 2        gas    160600        grey   11500    automatic  2013          honda
# 3        gas    199000       white    3300    automatic  1995           ford
# 4        gas    107292      silver    7000    automatic  2012             vw
# 5        gas     80245      silver   11500       manual  2015          chevy
# 6        gas     50280       black   31995    automatic  2015      chevrolet
# 7        gas    176000       white    3900    automatic  2000          lexus
# 8        gas    165000     unknown    8500    automatic  2005            bmw
# 9        gas     55000     unknown   18500    automatic  2017         toyota
# 10       gas    142000       black   10500    automatic  2014        hyundai
# 11       gas     41300       white   16500    automatic  2015          honda
# 12       gas     18000       black   34700    automatic  2018          honda
# 13       gas    133500        grey    7000    automatic  2006          honda
# 14       gas    220000       white    3000    automatic  2006          dodge
# 15       gas    260000     unknown    6000    automatic  2001          chevy
# 16       gas    120000      silver    3300    automatic  2003           ford
# 17       gas    230000     unknown    3000    automatic  2000          honda
# 18       gas    190000      silver    5800    automatic  2005         toyota
# 19       gas     16000        grey   69500    automatic  2021          range
# 20       gas     26192        blue   15200    automatic  2017         nissan
# 21       gas    108000         red   19500    automatic  2014          dodge
# 22  electric      4500     unknown  125000    automatic  2021          tesla
# 23       gas     64153       white    7700    automatic  2017          honda
# 24       gas    176000       green    4800    automatic  2003         toyota
# 25  electric     23000     unknown  122000    automatic  2020          tesla
# 26       gas    177000       black    5800    automatic  2008            kia
# 27       gas    176000       green    4800    automatic  2003         toyota
# 28       gas    246000     unknown    8500    automatic  2006          chevy
# 29       gas     90000       green   13500    automatic  2018         toyota
# 30       gas    188204     unknown    4500    automatic  2007           ford
# 31       gas    170000         red    1000    automatic  2003           ford
# 32       gas    172000       black    4200    automatic  2001  mercedes-benz
# 33       gas     30400       white   38000    automatic  2018         toyota
# 34       gas     92000        blue   18000    automatic  2016         toyota
# 35       gas    145000         red   12000    automatic  2003            gmc
# 36       gas    184000       black    3000    automatic  2002           jeep
# 37       gas    180000       white    4299    automatic  2008           saab
# 38       gas     70000     unknown    9500    automatic  2012         nissan
# 39       gas    120000        grey    7000    automatic  2012          chevy
# 40       gas     80000         red   12500    automatic  2003      silverado
# 41       gas    100000       black   13000    automatic  1970       cadillac
# 42       gas    100000     unknown   18000    automatic  1981          chevy
# 43       gas    198000        grey    5500    automatic  2009           ford
# 44       gas    148866       white    7500    automatic  2010           jeep
# 45       gas     99000     unknown    8800    automatic  1988          chevy
# 46       gas    100000       black    1500    automatic  2005          honda
# 47       gas     15743         red   21000       manual  1987           ford
# 48       gas    150000     unknown    3900    automatic  2005         nissan
# 49       gas    128909         red    2500    automatic  2006          buick
#
#          model               variant
# 0         road                runner
# 1        sc430               unknown
# 2        civic                 sedan
# 3          van               unknown
# 4        jetta               unknown
# 5       camaro               unknown
# 6    silverado           1500 lt 4x4
# 7        es300               unknown
# 8        325ci           convertible
# 9         rav4               unknown
# 10       santa              fe sport
# 11       civic            ex-l sedan
# 12         crv             (touring)
# 13      accord               unknown
# 14     durango               unknown
# 15   silverado               unknown
# 16     mustang               unknown
# 17      accord               unknown
# 18        rav4               unknown
# 19       rover                 velar
# 20      altima               unknown
# 21         ram                  1500
# 22       model          x long range
# 23      accord                 sport
# 24       camry               le 2003
# 25       model                     x
# 26     sorento               unknown
# 27       camry               le 2003
# 28   silverado              crew cab
# 29     corolla               unknown
# 30      escape                   xlt
# 31       focus               unknown
# 32      slk230            kompressor
# 33      tacoma        double cab sr5
# 34        rav4               unknown
# 35      sierra               unknown
# 36       grand  cherokee limited 4x4
# 37         9-3                  2.0t
# 38      maxima               unknown
# 39      camaro               unknown
# 40     unknown               unknown
# 41     deville               unknown
# 42         c10               unknown
# 43      escape               unknown
# 44   commander               unknown
# 45         r10               unknown
# 46      accord               unknown
# 47     mustang               unknown
# 48       rogue               unknown
# 49  rendezvous               unknown

# %% [markdown]
# ### Save data frame as csv

# %%
craiglist.to_csv('craiglist_clean.csv', index=False)
